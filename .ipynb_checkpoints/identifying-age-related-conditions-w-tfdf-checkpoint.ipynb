# %% [markdown]
# # Prelude

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %% [markdown]
# ## Load the Dataset

# %%
dataset_df = pd.read_csv("train.csv")
print("Full train dataset shape is {}".format(dataset_df.shape))
# Out:
# Full train dataset shape is (617, 58)

# %% [markdown]
# The data is composed of 58 columns and 617 entries. We can see all 58 dimensions(results will be truncated since the number of columns is big) of our dataset by printing out the first 5 entries using the following code:

# %%
dataset_df.head()
# Out:
#              Id        AB          AF          AH         AM        AR  \
# 0  000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688
# 1  007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688
# 2  013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688
# 3  043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688
# 4  044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688
#
#          AX        AY         AZ          BC  ...        FL        FR  \
# 0  0.699861  0.025578   9.812214    5.555634  ...  7.298162   1.73855
# 1  3.632190  0.025578  13.517790    1.229900  ...  0.173229   0.49706
# 2  6.732840  0.025578  12.824570    1.229900  ...  7.709560   0.97556
# 3  3.685344  0.025578  11.053708    1.229900  ...  6.122162   0.49706
# 4  3.942255  0.054810   3.396778  102.151980  ...  8.153058  48.50134
#
#          FS         GB          GE            GF         GH         GI  \
# 0  0.094822  11.339138   72.611063   2003.810319  22.136229  69.834944
# 1  0.568932   9.292698   72.611063  27981.562750  29.135430  32.131996
# 2  1.198821  37.077772   88.609437  13676.957810  28.022851  35.192676
# 3  0.284466  18.529584   82.416803   2094.262452  39.948656  90.493248
# 4  0.121914  16.408728  146.109943   8524.370502  45.381316  36.262628
#
#           GL  Class
# 0   0.120343      1
# 1  21.978000      0
# 2   0.196941      0
# 3   0.155829      0
# 4   0.096614      1
#
# [5 rows x 58 columns]

# %% [markdown]
# `Class` is the label column indicating if a person has one or more of any of the three medical conditions (i.e,`Class 1`), or none of the three medical conditions (i.e,`Class 0`).
# Given the features of the dataset, the goal of our model is to predict the value of `Class` for any person.

# %% [markdown]
# ## Quick basic dataset exploration

# %%
dataset_df.describe()
# Out:
#                AB            AF           AH          AM          AR  \
# count  617.000000    617.000000   617.000000  617.000000  617.000000
# mean     0.477149   3502.013221   118.624513   38.968552   10.128242
# std      0.468388   2300.322717   127.838950   69.728226   10.518877
# min      0.081187    192.593280    85.200147    3.177522    8.138688
# 25%      0.252107   2197.345480    85.200147   12.270314    8.138688
# 50%      0.354659   3120.318960    85.200147   20.533110    8.138688
# 75%      0.559763   4361.637390   113.739540   39.139886    8.138688
# max      6.161666  28688.187660  1910.123198  630.518230  178.943634
#
#                AX          AY          AZ           BC           BD   ...  \
# count  617.000000  617.000000  617.000000   617.000000    617.000000  ...
# mean     5.545576    0.060320   10.566447     8.053012   5350.388655  ...
# std      2.551696    0.416817    4.350645    65.166943   3021.326641  ...
# min      0.699861    0.025578    3.396778     1.229900   1693.624320  ...
# 25%      4.128294    0.025578    8.129580     1.229900   4155.702870  ...
# 50%      5.031912    0.025578   10.461320     1.229900   4997.960730  ...
# 75%      6.431634    0.036845   12.969516     5.081244   6035.885700  ...
# max     38.270880   10.315851   38.971568  1463.693448  53060.599240  ...
#
#                FL           FR          FS          GB           GE  \
# count  616.000000   617.000000  615.000000  617.000000   617.000000
# mean     5.433199     3.533905    0.421501   20.724856   131.714987
# std     11.496257    50.181948    1.305365    9.991907   144.181524
# min      0.173229     0.497060    0.067730    4.102182    72.611063
# 25%      0.173229     0.497060    0.067730   14.036718    72.611063
# 50%      3.028141     1.131000    0.250601   18.771436    72.611063
# 75%      6.238814     1.512060    0.535067   25.608406   127.591671
# max    137.932739  1244.227020   31.365763  135.781294  1497.351958
#
#                   GF          GH          GI          GL       Class
# count     617.000000  617.000000  617.000000  616.000000  617.000000
# mean    14679.595398   31.489716   50.584437    8.530961    0.175041
# std     19352.959387    9.864239   36.266251   10.327010    0.380310
# min        13.038894    9.432735    0.897628    0.001129    0.000000
# 25%      2798.992584   25.034888   23.011684    0.124392    0.000000
# 50%      7838.273610   30.608946   41.007968    0.337827    0.000000
# 75%     19035.709240   36.863947   67.931664   21.978000    0.000000
# max    143790.071200   81.210825  191.194764   21.978000    1.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# # Main Action

# %% [markdown]
# ## Data Cleaning

# %%
data_clean_0 = dataset_df[dataset_df.columns[1:-1]]
data_clean
# Out:
#            AB          AF          AH          AM         AR        AX  \
# 0    0.209377  3109.03329   85.200147   22.394407   8.138688  0.699861
# 1    0.145282   978.76416   85.200147   36.968889   8.138688  3.632190
# 2    0.470030  2635.10654   85.200147   32.360553   8.138688  6.732840
# 3    0.252107  3819.65177  120.201618   77.112203   8.138688  3.685344
# 4    0.380297  3733.04844   85.200147   14.103738   8.138688  3.942255
# ..        ...         ...         ...         ...        ...       ...
# 612  0.149555  3130.05946  123.763599    9.513984  13.020852  3.499305
# 613  0.435846  5462.03438   85.200147   46.551007  15.973224  5.979825
# 614  0.427300  2459.10720  130.138587   55.355778  10.005552  8.070549
# 615  0.363205  1263.53524   85.200147   23.685856   8.138688  7.981959
# 616  0.482849  2672.53426  546.663930  112.006102   8.138688  3.198099
#
#            AY         AZ          BC         BD   ...         FL        FR  \
# 0    0.025578   9.812214    5.555634  4126.58731  ...   7.298162   1.73855
# 1    0.025578  13.517790    1.229900  5496.92824  ...   0.173229   0.49706
# 2    0.025578  12.824570    1.229900  5135.78024  ...   7.709560   0.97556
# 3    0.025578  11.053708    1.229900  4169.67738  ...   6.122162   0.49706
# 4    0.054810   3.396778  102.151980  5728.73412  ...   8.153058  48.50134
# ..        ...        ...         ...         ...  ...        ...       ...
# 612  0.077343   8.545512    2.804172  4157.68439  ...   0.173229   1.26092
# 613  0.025882  12.622906    3.777550  5654.07556  ...  10.223150   1.24236
# 614  0.025578  15.408390    1.229900  5888.87769  ...   0.173229   0.49706
# 615  0.025578   7.524588    1.229900  4517.86560  ...   9.256996   0.78764
# 616  0.116928   3.396778    7.948668  2818.01707  ...   0.173229   1.14492
#
#            FS         GB          GE            GF         GH          GI  \
# 0    0.094822  11.339138   72.611063   2003.810319  22.136229   69.834944
# 1    0.568932   9.292698   72.611063  27981.562750  29.135430   32.131996
# 2    1.198821  37.077772   88.609437  13676.957810  28.022851   35.192676
# 3    0.284466  18.529584   82.416803   2094.262452  39.948656   90.493248
# 4    0.121914  16.408728  146.109943   8524.370502  45.381316   36.262628
# ..        ...        ...         ...           ...        ...         ...
# 612  0.067730   8.967128  217.148554   8095.932828  24.640462   69.191944
# 613  0.426699  35.896418  496.994214   3085.308063  29.648928  124.808872
# 614  0.067730  19.962092  128.896894   6474.652866  26.166072  119.559420
# 615  0.670527  24.594488   72.611063   1965.343176  25.116750   37.155112
# 616  0.149006  13.673940   72.611063   6850.484442  45.745974  114.842372
#
#             GL  Class
# 0     0.120343      1
# 1    21.978000      0
# 2     0.196941      0
# 3     0.155829      0
# 4     0.096614      1
# ..         ...    ...
# 612  21.978000      0
# 613   0.145340      0
# 614  21.978000      0
# 615   0.184622      0
# 616  21.978000      0
#
# [617 rows x 57 columns]

# %%
data_clean["EJ"] = dataset_df.EJ.transform(lambda x: -1 if x == "A" else 1)
# Out:
# /var/folders/4v/d5gkqj415zs229wq5xyxk1cc0000gn/T/ipykernel_23844/1436834435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["EJ"] = dataset_df.EJ.transform(lambda x: -1 if x == "A" else 1)

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 57 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AB      617 non-null    float64
#  1   AF      617 non-null    float64
#  2   AH      617 non-null    float64
#  3   AM      617 non-null    float64
#  4   AR      617 non-null    float64
#  5   AX      617 non-null    float64
#  6   AY      617 non-null    float64
#  7   AZ      617 non-null    float64
#  8   BC      617 non-null    float64
#  9   BD      617 non-null    float64
#  10  BN      617 non-null    float64
#  11  BP      617 non-null    float64
#  12  BQ      557 non-null    float64
#  13  BR      617 non-null    float64
#  14  BZ      617 non-null    float64
#  15  CB      615 non-null    float64
#  16  CC      614 non-null    float64
#  17  CD      617 non-null    float64
#  18  CF      617 non-null    float64
#  19  CH      617 non-null    float64
#  20  CL      617 non-null    float64
#  21  CR      617 non-null    float64
#  22  CS      617 non-null    float64
#  23  CU      617 non-null    float64
#  24  CW      617 non-null    float64
#  25  DA      617 non-null    float64
#  26  DE      617 non-null    float64
#  27  DF      617 non-null    float64
#  28  DH      617 non-null    float64
#  29  DI      617 non-null    float64
#  30  DL      617 non-null    float64
#  31  DN      617 non-null    float64
#  32  DU      616 non-null    float64
#  33  DV      617 non-null    float64
#  34  DY      617 non-null    float64
#  35  EB      617 non-null    float64
#  36  EE      617 non-null    float64
#  37  EG      617 non-null    float64
#  38  EH      617 non-null    float64
#  39  EJ      617 non-null    int64
#  40  EL      557 non-null    float64
#  41  EP      617 non-null    float64
#  42  EU      617 non-null    float64
#  43  FC      616 non-null    float64
#  44  FD      617 non-null    float64
#  45  FE      617 non-null    float64
#  46  FI      617 non-null    float64
#  47  FL      616 non-null    float64
#  48  FR      617 non-null    float64
#  49  FS      615 non-null    float64
#  50  GB      617 non-null    float64
#  51  GE      617 non-null    float64
#  52  GF      617 non-null    float64
#  53  GH      617 non-null    float64
#  54  GI      617 non-null    float64
#  55  GL      616 non-null    float64
#  56  Class   617 non-null    int64
# dtypes: float64(55), int64(2)
# memory usage: 274.9 KB

# %%
data_clean.isnull().values.any()
# Out:
# True

# %%
data_filler = SimpleImputer(strategy  = "median")
data_clean[data_clean["Class"] == 0] = pd.DataFrame(data_filler.fit_transform(data_clean[data_clean["Class"] == 0]), columns = data_clean.columns)
data_clean[data_clean["Class"] == 1] = pd.DataFrame(data_filler.fit_transform(data_clean[data_clean["Class"] == 1]), columns = data_clean.columns)
data_clean
# Out:
# /var/folders/4v/d5gkqj415zs229wq5xyxk1cc0000gn/T/ipykernel_23844/3216141484.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean[data_clean["Class"] == 0] = pd.DataFrame(data_filler.fit_transform(data_clean[data_clean["Class"] == 0]), columns = data_clean.columns)
# /var/folders/4v/d5gkqj415zs229wq5xyxk1cc0000gn/T/ipykernel_23844/3216141484.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean[data_clean["Class"] == 1] = pd.DataFrame(data_filler.fit_transform(data_clean[data_clean["Class"] == 1]), columns = data_clean.columns)
# /var/folders/4v/d5gkqj415zs229wq5xyxk1cc0000gn/T/ipykernel_23844/3216141484.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean[data_clean["Class"] == 1] = pd.DataFrame(data_filler.fit_transform(data_clean[data_clean["Class"] == 1]), columns = data_clean.columns)
#            AB          AF          AH         AM        AR        AX  \
# 0    0.209377  3109.03329   85.200147  22.394407  8.138688  0.699861
# 1    0.470030  2635.10654   85.200147  32.360553  8.138688  6.732840
# 2    0.252107  3819.65177  120.201618  77.112203  8.138688  3.685344
# 3    0.209377  2615.81430   85.200147   8.541526  8.138688  4.013127
# 4    0.743502  3447.90831   85.200147  79.431856  8.138688  5.262246
# ..        ...         ...         ...        ...       ...       ...
# 612       NaN         NaN         NaN        NaN       NaN       NaN
# 613       NaN         NaN         NaN        NaN       NaN       NaN
# 614       NaN         NaN         NaN        NaN       NaN       NaN
# 615       NaN         NaN         NaN        NaN       NaN       NaN
# 616       NaN         NaN         NaN        NaN       NaN       NaN
#
#            AY         AZ         BC         BD   ...        FL       FR  \
# 0    0.025578   9.812214   5.555634  4126.58731  ...  7.298162  1.73855
# 1    0.025578  12.824570   1.229900  5135.78024  ...  7.709560  0.97556
# 2    0.025578  11.053708   1.229900  4169.67738  ...  6.122162  0.49706
# 3    0.025578  12.547282   1.229900  5237.54088  ...  0.173229  0.49706
# 4    0.025578  12.364524  11.026932  8264.97585  ...  9.347391  1.71564
# ..        ...        ...        ...         ...  ...       ...      ...
# 612       NaN        NaN        NaN         NaN  ...       NaN      NaN
# 613       NaN        NaN        NaN         NaN  ...       NaN      NaN
# 614       NaN        NaN        NaN         NaN  ...       NaN      NaN
# 615       NaN        NaN        NaN         NaN  ...       NaN      NaN
# 616       NaN        NaN        NaN         NaN  ...       NaN      NaN
#
#            FS         GB         GE            GF         GH         GI  \
# 0    0.094822  11.339138  72.611063   2003.810319  22.136229  69.834944
# 1    1.198821  37.077772  88.609437  13676.957810  28.022851  35.192676
# 2    0.284466  18.529584  82.416803   2094.262452  39.948656  90.493248
# 3    1.164956  21.915512  72.611063  24177.595550  28.525186  82.527764
# 4    0.954993  24.734018  72.611063   2189.644083  37.556053  54.655000
# ..        ...        ...        ...           ...        ...        ...
# 612       NaN        NaN        NaN           NaN        NaN        NaN
# 613       NaN        NaN        NaN           NaN        NaN        NaN
# 614       NaN        NaN        NaN           NaN        NaN        NaN
# 615       NaN        NaN        NaN           NaN        NaN        NaN
# 616       NaN        NaN        NaN           NaN        NaN        NaN
#
#             GL  Class
# 0     0.120343    1.0
# 1     0.196941    0.0
# 2     0.155829    0.0
# 3    21.978000    0.0
# 4     0.083250    1.0
# ..         ...    ...
# 612        NaN    NaN
# 613        NaN    NaN
# 614        NaN    NaN
# 615        NaN    NaN
# 616        NaN    NaN
#
# [617 rows x 57 columns]

# %%
data_clean.isnull().values.any()
# Out:
# True

# %%
feature_reducer = PCA()
feature_reducer.fit(data_clean)
plt.plot(feature_reducer.explained_variance_ratio_)
np.sum(feature_reducer.explained_variance_ratio_[:5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 feature_reducer = PCA()
# ----> 2 feature_reducer.fit(data_clean)
#       3 plt.plot(feature_reducer.explained_variance_ratio_)
#       4 np.sum(feature_reducer.explained_variance_ratio_[:5])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:382, in PCA.fit(self, X, y)
#     365 def fit(self, X, y=None):
#     366     """Fit the model with X.
#     367
#     368     Parameters
#    (...)
#     380         Returns the instance itself.
#     381     """
# --> 382     self._fit(X)
#     383     return self
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:430, in PCA._fit(self, X)
#     424 if issparse(X):
#     425     raise TypeError(
#     426         "PCA does not support sparse input. See "
#     427         "TruncatedSVD for a possible alternative."
#     428     )
# --> 430 X = self._validate_data(
#     431     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     432 )
#     434 # Handle n_components==None
#     435 if self.n_components is None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:800, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     794         raise ValueError(
#     795             "Found array with dim %d. %s expected <= 2."
#     796             % (array.ndim, estimator_name)
#     797         )
#     799     if force_all_finite:
# --> 800         _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     802 if ensure_min_samples > 0:
#     803     n_samples = _num_samples(array)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:114, in _assert_all_finite(X, allow_nan, msg_dtype)
#     107     if (
#     108         allow_nan
#     109         and np.isinf(X).any()
#     110         or not allow_nan
#     111         and not np.isfinite(X).all()
#     112     ):
#     113         type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114         raise ValueError(
#     115             msg_err.format(
#     116                 type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117             )
#     118         )
#     119 # for object dtype data, we only check for NaNs (GH-13254)
#     120 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
data_clean = pd.DataFrame(feature_reducer.transform(data_clean)[:, :5])
data_clean
# Out:
#                 0            1            2            3            4
# 0   -12649.368353 -1430.232664  -465.966144 -1253.172770  -561.498671
# 1    13391.309580 -3461.908345  -926.947110  -159.953240 -2295.433601
# 2     -959.356480 -2018.232389  -679.742573  -386.416963  -858.094762
# 3   -12546.720847   431.349327  -727.487405  -788.803266  3021.173690
# 4    -6262.279743  5993.156353  4586.964060   138.803934   -75.094529
# ..            ...          ...          ...          ...          ...
# 612  -6636.397941  6754.526259 -1147.068294 -1293.867390  -745.049386
# 613 -11700.086205  8031.832264 -1104.402061   164.487979  1576.134585
# 614  -8136.716757 -5293.249275   957.962901   289.851526  -948.754875
# 615 -12626.456148 -4025.173108  -486.791420 -1025.635577 -2372.800068
# 616  -7767.102543 -4518.910289  -379.599588 -2381.619232  -873.948216
#
# [617 rows x 5 columns]

# %%
data_clean["Id"] = dataset_df["Id"]
data_clean["Class"] = dataset_df["Class"]
data_clean
# Out:
#                 0            1            2            3            4  \
# 0   -12649.368353 -1430.232664  -465.966144 -1253.172770  -561.498671
# 1    13391.309580 -3461.908345  -926.947110  -159.953240 -2295.433601
# 2     -959.356480 -2018.232389  -679.742573  -386.416963  -858.094762
# 3   -12546.720847   431.349327  -727.487405  -788.803266  3021.173690
# 4    -6262.279743  5993.156353  4586.964060   138.803934   -75.094529
# ..            ...          ...          ...          ...          ...
# 612  -6636.397941  6754.526259 -1147.068294 -1293.867390  -745.049386
# 613 -11700.086205  8031.832264 -1104.402061   164.487979  1576.134585
# 614  -8136.716757 -5293.249275   957.962901   289.851526  -948.754875
# 615 -12626.456148 -4025.173108  -486.791420 -1025.635577 -2372.800068
# 616  -7767.102543 -4518.910289  -379.599588 -2381.619232  -873.948216
#
#                Id  Class
# 0    000ff2bfdfe9      1
# 1    007255e47698      0
# 2    013f2bd269f5      0
# 3    043ac50845d5      0
# 4    044fb8a146ec      1
# ..            ...    ...
# 612  fd3dafe738fd      0
# 613  fd895603f071      0
# 614  fd8ef6377f76      0
# 615  fe1942975e40      0
# 616  ffcca4ded3bb      0
#
# [617 rows x 7 columns]

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       617 non-null    float64
#  1   1       617 non-null    float64
#  2   2       617 non-null    float64
#  3   3       617 non-null    float64
#  4   4       617 non-null    float64
#  5   Id      617 non-null    object
#  6   Class   617 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 33.9+ KB

# %%
data_clean.describe()
# Out:
#                   0             1             2             3             4  \
# count  6.170000e+02  6.170000e+02  6.170000e+02  6.170000e+02  6.170000e+02
# mean  -2.772706e-12 -3.920998e-13 -8.291585e-16 -1.474059e-13 -5.971783e-13
# std    1.935805e+04  1.133655e+04  7.568087e+03  3.413933e+03  2.277334e+03
# min   -1.483159e+04 -8.802149e+03 -5.577603e+03 -3.278302e+03 -3.681858e+03
# 25%   -1.189612e+04 -5.169880e+03 -7.996909e+02 -1.093365e+03 -1.241635e+03
# 50%   -6.881214e+03 -2.939855e+03 -4.867914e+02 -3.416103e+02 -3.645490e+02
# 75%    4.405234e+03  3.502949e+02 -1.223618e+02  5.985837e+02  8.710672e+02
# max    1.291463e+05  1.327159e+05  1.774758e+05  6.598899e+04  2.447210e+04
#
#             Class
# count  617.000000
# mean     0.175041
# std      0.380310
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
plt.plot(data_clean[data_clean["Class"] == 0][0], data_clean[data_clean["Class"] == 0][1], '.', label = "0")
plt.plot(data_clean[data_clean["Class"] == 1][0], data_clean[data_clean["Class"] == 1][1], '.', label = "1")
plt.axis("equal")
plt.legend()
plt.show()

# %% [markdown]
# ### Pie chart for label column: Class

# %%
plot_df = data_clean.Class.value_counts()
plot_df.plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Class'>

# %% [markdown]
# **Important**: From the pie chart we can see that the dataset is heavily imbalanced since the fraction of positive(`1`) samples is very small compared to the negative(`0`) samples.

# %% [markdown]
# ### Now let us create the data matrix and prediction vector in the standard format

# %%
X_0 = np.array(data_clean[data_clean["Class"] == 0][data_clean.columns[:5]])
y_0 = np.array(data_clean[data_clean["Class"] == 0]["Class"])

X_1 = np.array(data_clean[data_clean["Class"] == 1][data_clean.columns[:5]])
y_1 = np.array(data_clean[data_clean["Class"] == 1]["Class"])

X_0.shape, y_0.shape, X_1.shape, y_1.shape
# Out:
# ((509, 5), (509,), (108, 5), (108,))

# %% [markdown]
# The missing values are treated speartaely for each class as can be seen in the code below

# %% [markdown]
# ### Create a train test split

# %%
X_train_0, X_valid_0, y_train_0, y_valid_0 = train_test_split(X_0, y_0, test_size = 5, train_size = 103, random_state = 69)
#X_train_0, X_valid_0, y_train_0, y_valid_0 = train_test_split(X_0, y_0, test_size = 5, random_state = 69)
X_train_1, X_valid_1, y_train_1, y_valid_1 = train_test_split(X_1, y_1, test_size = 5, random_state = 69)

X_train = np.append(X_train_1, X_train_0, axis = 0)
y_train = np.append(y_train_1, y_train_0, axis = 0)
X_valid = np.append(X_valid_0, X_valid_1, axis = 0)
y_valid = np.append(y_valid_0, y_valid_1, axis = 0)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((206, 5), (206,), (10, 5), (10,))

# %%
plt.plot(y_valid, '.')

# %% [markdown]
# ## Training

# %%
start_time = time.time()

#model = MLPClassifier(max_iter = 10000000, solver = "lbfgs", tol = 1e-8)
model = SVC(probability = True)
model.fit(X_train, y_train)

end_time = time.time()
print("Time taken to train the model:", (end_time - start_time), "seconds")
# Out:
# Time taken to train the model: 0.016870975494384766 seconds

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 5))
ax.plot(np.abs(y_train - model.predict(X_train)), '.')
ax.set_title("Diff in prediction")
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 5))
ax.plot(model.loss_curve_, '.')
ax.set_title("Loss value time series")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#       1 fig, ax = plt.subplots(1, 1, figsize = (10, 5))
# ----> 2 ax.plot(model.loss_curve_, '.')
#       3 ax.set_title("Loss value time series")
#       4 plt.show()
#
# AttributeError: 'SVC' object has no attribute 'loss_curve_'

# %% [markdown]
# ### Performance on the training set

# %% [markdown]
# Let's find the competition score on the training set

# %%
N0 = np.sum(y_train == 0)
N1 = np.sum(y_train == 1)

predictions_train = model.predict_proba(X_train)

score = 0
epsilon = 10 ** -15

for i in range(len(y_train)):
    if y_train[i] == 0:
        p = max(min(predictions_train[i][0], 1.0 - epsilon), epsilon)
        score -= np.log(p) / N0
    else:
        p = max(min(predictions_train[i][1], 1.0 - epsilon), epsilon)
        score -= np.log(p) / N1

score /= 2
print("Balanced logarithmic loss score on training data :", score)
# Out:
# Balanced logarithmic loss score on training data : 0.5966451093332552

# %% [markdown]
# ## Performance on the validation set

# %%
N0 = np.sum(y_valid == 0)
N1 = np.sum(y_valid == 1)

predictions_valid = model.predict_proba(X_valid)

score = 0
epsilon = 10 ** -15

for i in range(len(y_valid)):
    if y_valid[i] == 0:
        p = max(min(predictions_valid[i][0], 1.0 - epsilon), epsilon)
        score -= np.log(p) / N0
    else:
        p = max(min(predictions_valid[i][1], 1.0 - epsilon), epsilon)
        score -= np.log(p) / N1

score /= 2
print("Balanced logarithmic loss score on validation data :", score)
# Out:
# Balanced logarithmic loss score on validation data : 0.4590857333478529

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 5))
ax.plot(y_valid - model.predict(X_valid), '.')
ax.set_title("Diff in prediction")
plt.show()

# %% [markdown]
# # More context

# %% [markdown]
# ## Understanding the numerical implications of a right prediction and a wrong one

# %%
1- epsilon, -np.log(1 - epsilon)
# Out:
# (0.999999999999999, 9.992007221626415e-16)

# %%
epsilon, -np.log(epsilon)
# Out:
# (1e-15, 34.538776394910684)
